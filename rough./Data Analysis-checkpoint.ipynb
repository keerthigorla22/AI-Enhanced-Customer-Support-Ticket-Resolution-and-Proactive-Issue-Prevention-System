# %%
import pandas as pd
df = pd.read_csv("C:/Users/KEERTHI/OneDrive/Desktop/customer_support_tickets.csv")
df.head()
# Out:
#    Ticket ID        Customer Name              Customer Email  Customer Age  \
# 0          1        Marisa Obrien  carrollallison@example.com            32
# 1          2         Jessica Rios    clarkeashley@example.com            42
# 2          3  Christopher Robbins   gonzalestracy@example.com            48
# 3          4     Christina Dillon    bradleyolson@example.org            27
# 4          5    Alexander Carroll     bradleymark@example.com            67
#
#   Customer Gender Product Purchased Date of Purchase      Ticket Type  \
# 0           Other        GoPro Hero       2021-03-22  Technical issue
# 1          Female       LG Smart TV       2021-05-22  Technical issue
# 2           Other          Dell XPS       2020-07-14  Technical issue
# 3          Female  Microsoft Office       2020-11-13  Billing inquiry
# 4          Female  Autodesk AutoCAD       2020-02-04  Billing inquiry
#
#              Ticket Subject  \
# 0             Product setup
# ...

# %%
df.shape
# Out:
# (8469, 17)

# %%
df["Product Purchased"]
# Out:
# 0                   GoPro Hero
# 1                  LG Smart TV
# 2                     Dell XPS
# 3             Microsoft Office
# 4             Autodesk AutoCAD
#                  ...
# 8464                   LG OLED
# 8465    Bose SoundLink Speaker
# 8466       GoPro Action Camera
# 8467               PlayStation
# 8468        Philips Hue Lights
# Name: Product Purchased, Length: 8469, dtype: object

# %%
df.columns
# Out:
# Index(['Ticket ID', 'Customer Name', 'Customer Email', 'Customer Age',
#        'Customer Gender', 'Product Purchased', 'Date of Purchase',
#        'Ticket Type', 'Ticket Subject', 'Ticket Description', 'Ticket Status',
#        'Resolution', 'Ticket Priority', 'Ticket Channel',
#        'First Response Time', 'Time to Resolution',
#        'Customer Satisfaction Rating'],
#       dtype='object')

# %%
df["Ticket Status"].unique()
# Out:
# array(['Pending Customer Response', 'Closed', 'Open'], dtype=object)

# %%
df["Product Purchased"].value_counts()
# Out:
# Product Purchased
# Canon EOS                         240
# GoPro Hero                        228
# Nest Thermostat                   225
# Philips Hue Lights                221
# Amazon Echo                       221
# LG Smart TV                       219
# Sony Xperia                       217
# Roomba Robot Vacuum               216
# Apple AirPods                     213
# LG OLED                           213
# iPhone                            212
# Sony 4K HDR TV                    210
# Garmin Forerunner                 208
# LG Washing Machine                208
# Canon DSLR Camera                 206
# Nikon D                           204
# Nintendo Switch Pro Controller    203
# Google Pixel                      203
# Fitbit Charge                     202
# Sony PlayStation                  202
# HP Pavilion                       200
# Microsoft Office                  200
# Amazon Kindle                     198
# Google Nest                       198
# ...

# %%
df["Ticket Type"].unique()
# Out:
# array(['Technical issue', 'Billing inquiry', 'Cancellation request',
#        'Product inquiry', 'Refund request'], dtype=object)

# %%
df["Ticket Type"].value_counts()
# Out:
# Ticket Type
# Refund request          1752
# Technical issue         1747
# Cancellation request    1695
# Product inquiry         1641
# Billing inquiry         1634
# Name: count, dtype: int64

# %%
df.loc[df["Ticket Subject"].eq("Cancellation request"), :]
# Out:
#       Ticket ID     Customer Name               Customer Email  Customer Age  \
# 26           27        Ryan Sharp         pmercado@example.org            22
# 29           30     Austin George        shericase@example.net            67
# 45           46    Timothy Sutton          david40@example.org            65
# 59           60  Samuel Schroeder         andrew28@example.org            40
# 81           82      Kiara Parker    gonzalezlarry@example.org            29
# ...         ...               ...                          ...           ...
# 8381       8382      David Wilson        anthony00@example.com            51
# 8397       8398  Richard Mccarthy          xbailey@example.com            59
# 8406       8407      Tyler Obrien        tammymoss@example.org            69
# 8421       8422        Leah Davis      chenrebecca@example.net            47
# 8438       8439      Andrea Bates  kristinasherman@example.com            19
#
# ...

# %%
df["Ticket Subject"].unique()
# Out:
# array(['Product setup', 'Peripheral compatibility', 'Network problem',
#        'Account access', 'Data loss', 'Payment issue', 'Refund request',
#        'Battery life', 'Installation support', 'Software bug',
#        'Hardware issue', 'Product recommendation', 'Delivery problem',
#        'Display issue', 'Cancellation request', 'Product compatibility'],
#       dtype=object)

# %%
df["Ticket Subject"].value_counts()
# Out:
# Ticket Subject
# Refund request              576
# Software bug                574
# Product compatibility       567
# Delivery problem            561
# Hardware issue              547
# Battery life                542
# Network problem             539
# Installation support        530
# Product setup               529
# Payment issue               526
# Product recommendation      517
# Account access              509
# Peripheral compatibility    496
# Data loss                   491
# Cancellation request        487
# Display issue               478
# Name: count, dtype: int64

# %%
#MOST COMMONLY OCCURING ISSUES

# %%
df2 = df.loc[df["Ticket Status"].eq("Closed"), :].reset_index(False)

# %%
df2.shape
# Out:
# (2769, 18)

# %%
df2["Customer Satisfaction Rating"].value_counts()
# Out:
# Customer Satisfaction Rating
# 3.0    580
# 1.0    553
# 2.0    549
# 5.0    544
# 4.0    543
# Name: count, dtype: int64

# %%
df2["Ticket Type"].value_counts()
# Out:
# Ticket Type
# Refund request          596
# Technical issue         580
# Billing inquiry         544
# Product inquiry         533
# Cancellation request    516
# Name: count, dtype: int64

# %%
df2["Ticket Subject"].value_counts()
# Out:
# Ticket Subject
# Network problem             201
# Software bug                199
# Product compatibility       195
# Product recommendation      186
# Product setup               183
# Hardware issue              183
# Delivery problem            178
# Refund request              178
# Battery life                173
# Account access              171
# Installation support        158
# Peripheral compatibility    158
# Payment issue               156
# Display issue               155
# Cancellation request        148
# Data loss                   147
# Name: count, dtype: int64

# %%
df3 = df2.loc[df2["Customer Satisfaction Rating"].eq(5), :]

# %%
df3.shape
# Out:
# (544, 18)

# %%
df3.head(20)
# Out:
#     index  Ticket ID      Customer Name               Customer Email  \
# 7      19         20  Jeffrey Robertson       jameslopez@example.com
# 8      28         29     Christine Wang      garciastacy@example.com
# 11     33         34      Timothy Lyons       darlenelee@example.org
# 21     58         59      Kimberly Mack      lwilliamson@example.net
# 25     66         67     John Robertson  gillespiegeorge@example.com
# 30     77         78       Alfred Ortiz   nicholsdouglas@example.org
# 33     89         90          Lisa Hill      hinescarrie@example.org
# 34     95         96     Linda Campbell     davisnatalie@example.net
# 35     98         99      Nichole Huang     sheryldawson@example.org
# 42    116        117      Sabrina Weber     eblankenship@example.net
# 43    117        118       Glenda Lopez           mary68@example.net
# 47    133        134        Jill Walker       nicholas74@example.com
# 60    164        165     Rebecca Patton      ballwilliam@example.com
# ...

# %%
df3["Ticket Type"].value_counts()
# Out:
# Ticket Type
# Refund request          115
# Technical issue         113
# Cancellation request    112
# Billing inquiry         109
# Product inquiry          95
# Name: count, dtype: int64

# %%
df3["Ticket Subject"].value_counts()
# Out:
# Ticket Subject
# Software bug                38
# Account access              38
# Installation support        37
# Payment issue               37
# Product compatibility       35
# Delivery problem            35
# Refund request              35
# Product recommendation      34
# Battery life                34
# Hardware issue              33
# Network problem             33
# Data loss                   33
# Display issue               32
# Product setup               31
# Cancellation request        31
# Peripheral compatibility    28
# Name: count, dtype: int64

# %%
df3.head(10)
# Out:
#     index  Ticket ID      Customer Name               Customer Email  \
# 7      19         20  Jeffrey Robertson       jameslopez@example.com
# 8      28         29     Christine Wang      garciastacy@example.com
# 11     33         34      Timothy Lyons       darlenelee@example.org
# 21     58         59      Kimberly Mack      lwilliamson@example.net
# 25     66         67     John Robertson  gillespiegeorge@example.com
# 30     77         78       Alfred Ortiz   nicholsdouglas@example.org
# 33     89         90          Lisa Hill      hinescarrie@example.org
# 34     95         96     Linda Campbell     davisnatalie@example.net
# 35     98         99      Nichole Huang     sheryldawson@example.org
# 42    116        117      Sabrina Weber     eblankenship@example.net
#
#     Customer Age Customer Gender Product Purchased Date of Purchase  \
# 7             39          Female         Canon EOS       2021-03-08
# 8             30           Other     Fitbit Charge       2020-06-10
# ...

# %%
df3["Time Taken Bin"].unique()
# Out:
# ['15-19', '5-9', NaN, '0-4', '10-14', '20-24']
# Categories (5, object): ['0-4' < '5-9' < '10-14' < '15-19' < '20-24']

# %%
df4 = df3.loc[df3["Time Taken Bin"].eq("0-4"), :]

# %%
df4 = df3.loc[df3["Time Taken Bin"].eq("0-4"), :]

# %%
df4.head(20)
# Out:
#      index  Ticket ID      Customer Name               Customer Email  \
# 33      89         90          Lisa Hill      hinescarrie@example.org
# 43     117        118       Glenda Lopez           mary68@example.net
# 60     164        165     Rebecca Patton      ballwilliam@example.com
# 125    360        361        Andrea Cruz       sydneymoss@example.org
# 160    455        456       Denise Huang         amanda00@example.org
# 204    589        590      Jason Serrano     haleykenneth@example.net
# 262    763        764     Joshua Schmidt   michaelferrell@example.net
# 282    840        841     Jennifer Foley           zsolis@example.net
# 285    852        853        Luis Barton      dstrickland@example.org
# 318    944        945     Joshua Johnson            jon16@example.com
# 323    955        956      Andrew Mosley       kellytonya@example.net
# 333    999       1000     Bethany Krause    martinezsarah@example.com
# ...
